# %% [markdown]
# # Evaluate Models
#
# - enumerative search
# - neural guided search
# - CodeT5
# - LibT5

# %%
import datetime
import os
import random
import pandas as pd
import numpy as np
import operator
import random
from tqdm import tqdm
import dill
try:
    import binutil  # required to import from dreamcoder modules
except ModuleNotFoundError:
    import bin.binutil  # alt import if called as module

from dreamcoder.task import Task
from dreamcoder.dreamcoder import *
from dreamcoder.domains.minatar.primitives import basePrimitives, tmap, taction
from dreamcoder.grammar import Grammar
from dreamcoder.utilities import testTrainSplit, eprint, numberOfCPUs
from dreamcoder.type import arrow
from dreamcoder.domains.minatar.feature_extractor import *
from dreamcoder.dreamcoder import commandlineArguments
from dreamcoder.utilities import numberOfCPUs
from dreamcoder.domains.minatar.feature_extractor import convert_to_task_input
from dreamcoder.domains.minatar.utils_text_encoder import generate_samples_with_temp
import transformers
from transformers import RobertaTokenizer, T5ForConditionalGeneration
from dreamcoder.domains.minatar.utilities import *
os.environ["WANDB_PROJECT"] = "T5-Minatar"

def makeTasks(data, env_name, chunkSize, tolist=False):
    tasks = []
    examples = []
    part = 0
    states, actions, reward = data

    state_action_pairs = list(zip(states, actions))

    for i in range(len(state_action_pairs) - chunkSize):
        examples = []
        for state, action in state_action_pairs[i: i + chunkSize]:
            input_ex = (convert_to_task_input(state, jax_data=True, tolist=tolist),)
            output_ex = int(action)
            examples.append((input_ex, output_ex))

        # we check that the chosen actions are not all the same
        # otherwise it is too easy to find a program if all actions/output examples are the same
        # this results in programs such as (lambda (lambda forward-action))
        all_chosen_actions = list(zip(*examples))[1]
        if not all_equal(all_chosen_actions) and len(examples) == chunkSize:
            tasks.append(Task(f'{env_name} size {chunkSize} part {part}',
                              arrow(tmap, taction), examples))
            part += 1
    return tasks

# %%
def evaluate_enumerative_search(testingTasks, path):
    with open(path, "rb") as handle:
        result = dill.load(handle)
    resume = len(result.grammars) - 1
    eprint("Loaded checkpoint from", path)
    grammar = result.grammars[-1] if result.grammars else grammar
    args = commandlineArguments(
        enumerationTimeout=720,
        structurePenalty=1.5,
        recognitionSteps=5000,
        biasOptimal=False,
        contextual=False,
        a=3,
        topK=5,
        iterations=1,
        useRecognitionModel=True,
        helmholtzRatio=0.5,
        featureExtractor=MinigridMazeFeatureExtractor,
        maximumFrontier=10,
        CPUs=numberOfCPUs(),
        pseudoCounts=30.0,
        extras=None)
    times = evaluateOnTestingTasks(result, testingTasks, grammar,
                           CPUs=args.get('CPUs'), maximumFrontier=args.get('maximumFrontier'),
                           solver=args.get('solver'),
                           enumerationTimeout=args.get('enumerationTimeout'), evaluationTimeout=args.get('enumerationTimeout'))

    return times

def check_test_tasks(testTasks, grammar, generate_sample_fn, n_sampling=100, verbose=False):
    stats = []
    solved_tasks = set()
    solved = 0
    for tt in (pbar := tqdm(testTasks)):
        p, n = test_programs_on_task(tt, grammar, generate_sample_fn, n=n_sampling, verbose=verbose, use_multiprocess=True)
        stats.append((p, n))
        if 'random' not in str(tt[1]):
            solved_tasks.add(tuple([str(tt[1]), str(p)]))

        if p is not None:
            solved += 1
        pbar.set_description(f"Solved: {solved}")
    return stats, solved_tasks, solved

def evaluate_T5(testingTasks, path, iter_folder, env_name, no_spaces=True, compress=False):
    feature_extractor = MinatarFeatureExtractorToken(
        env_name=env_name, max_steps=500, no_spaces=no_spaces, compress=compress)
    #testingTasks = feature_extractor.create_test_tasks(3)
    testTasks = createTestDataFromTasks(feature_extractor, testingTasks, True)
    checkpoint_dir = get_latest_checkpoint_path(path)
    model = T5ForConditionalGeneration.from_pretrained(checkpoint_dir).to('cpu')
    model = model.eval()
    model = model.to('cuda')
    tokenizer = RobertaTokenizer.from_pretrained('Salesforce/codet5-base')
    grammar_file = os.path.join(path, iter_folder, 'results.pkl')
    with open(grammar_file, 'rb') as handle:
        result = dill.load(handle)
    grammar = [g['grammar'] for g in result.values()][-1]
    stats, solved_tasks, solved = check_test_tasks(
            testTasks, grammar, lambda x, y, z: generate_samples_with_temp(model, tokenizer, x, y, z, device='cuda'), n_sampling=500, verbose=True)
    return solved
    

def evaluate_model(data, path, iter_path, env_name, method, results_path):
    sequence_lengths = range(3, 31)
    solved_tasks = []
    idx = []
    for i in sequence_lengths:
        tasks = makeTasks(data, env_name, i)
        print(f'created {len(tasks)} tasks') 
        hits = method(tasks, path, iter_path, env_name)
        #return method(tasks, path, env_name)
        solved_tasks.append({
            'solved': hits,
            'tasks': len(tasks)
        })
        idx.append(i)
        df = pd.DataFrame(solved_tasks, index=idx)
        df.to_csv(results_path)  
    return df

# %%
# enum search
path = '../../../experimentOutputs/perfect-maze/2023-03-01T21:33:58.380983/maze_aic=1.0_arity=3_ET=720_it=39_MF=10_noConsolidation=False_pc=30.0_RS=10000_RW=False_solver=ocaml_STM=True_L=1.5_TRR=default_K=5_topkNotMAP=False_rec=False.pickle'


env_name = 'asterix' 
data = np.load(
        f"/home/ma/e/eberhardinger/workspaces/gymnax-blines/notebooks/{env_name}/rollouts.npy", allow_pickle=True)[0]

Grammar.uniform(basePrimitives(env_name))
df = evaluate_model(data, path, env_name, evaluate_enumerative_search, os.path.join(p, 'eval.csv'))
# Out:
# created 508 tasks
# loaded checkpoint from /home/ma/e/eberhardinger/workspaces/MinAtar/asterix_data_and_weights
#   0%|          | 0/508 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      14 Grammar.uniform(basePrimitives(env_name))
#      15 for p, iter_path in path:
# ---> 16     df = evaluate_model(data, p, iter_path, env_name, evaluate_T5, os.path.join(p, 'eval.csv'))
#
# Cell In[2], line 71, in evaluate_model(data, path, iter_path, env_name, method, results_path)
#      69 tasks = makeTasks(data, env_name, i)
#      70 print(f'created {len(tasks)} tasks')
# ---> 71 hits = method(tasks, path, iter_path, env_name)
#      72 #return method(tasks, path, env_name)
#      73 solved_tasks.append({
#      74     'solved': hits,
#      75     'tasks': len(tasks)
#      76 })
#
# Cell In[2], line 59, in evaluate_T5(testingTasks, path, iter_folder, env_name, no_spaces, compress)
#      57     result = dill.load(handle)
#      58 grammar = [g['grammar'] for g in result.values()][-1]
# ---> 59 stats, solved_tasks, solved = check_test_tasks(
#      60         testTasks, grammar, lambda x, y, z: generate_samples_with_temp(model, tokenizer, x, y, z, device='cuda'), n_sampling=500, verbose=True)
#      61 return solved
#
# Cell In[2], line 35, in check_test_tasks(testTasks, grammar, generate_sample_fn, n_sampling, verbose)
#      33 solved = 0
#      34 for tt in (pbar := tqdm(testTasks)):
# ---> 35     p, n = test_programs_on_task(tt, grammar, generate_sample_fn, n=n_sampling, verbose=verbose, use_multiprocess=True)
#      36     stats.append((p, n))
#      37     if 'random' not in str(tt[1]):
#
# File /home/ma/e/eberhardinger/workspaces/ec/bin/../dreamcoder/domains/minatar/utilities.py:352, in test_programs_on_task(task, grammar, generate_sample_fn, n, temp, verbose, use_multiprocess)
#     351 def test_programs_on_task(task, grammar, generate_sample_fn, n=5, temp=1.0, verbose=False, use_multiprocess=True):
# --> 352     progs = np.array(generate_sample_fn(task[0], n, temp))
#     353     num_progs = len(progs)
#     354     found_progs = []
#
# Cell In[2], line 60, in evaluate_T5.<locals>.<lambda>(x, y, z)
#      57     result = dill.load(handle)
#      58 grammar = [g['grammar'] for g in result.values()][-1]
#      59 stats, solved_tasks, solved = check_test_tasks(
# ---> 60         testTasks, grammar, lambda x, y, z: generate_samples_with_temp(model, tokenizer, x, y, z, device='cuda'), n_sampling=500, verbose=True)
#      61 return solved
#
# File /home/ma/e/eberhardinger/workspaces/ec/bin/../dreamcoder/domains/minatar/utils_text_encoder.py:41, in generate_samples_with_temp(model, tokenizer, txt, n_samples, temp, device)
#      39 for i in range(outer_loop):
#      40     to_tokenizer = [txt for j in range(20)]
# ---> 41     outputs = model.generate(tokenizer(to_tokenizer, return_tensors='pt', padding=True).input_ids.to(
#      42         device), do_sample=True, max_length=128, temperature=temp)
#      43     results += tokenizer.batch_decode(outputs, skip_special_tokens=True)
#      44     temp = temp - 0.005
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/generation/utils.py:1452, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, **kwargs)
#    1444     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1445         input_ids=input_ids,
#    1446         expand_size=generation_config.num_return_sequences,
#    1447         is_encoder_decoder=self.config.is_encoder_decoder,
#    1448         **model_kwargs,
#    1449     )
#    1451     # 13. run sample
# -> 1452     return self.sample(
#    1453         input_ids,
#    1454         logits_processor=logits_processor,
#    1455         logits_warper=logits_warper,
#    1456         stopping_criteria=stopping_criteria,
#    1457         pad_token_id=generation_config.pad_token_id,
#    1458         eos_token_id=generation_config.eos_token_id,
#    1459         output_scores=generation_config.output_scores,
#    1460         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1461         synced_gpus=synced_gpus,
#    1462         **model_kwargs,
#    1463     )
#    1465 elif is_beam_gen_mode:
#    1466     if generation_config.num_return_sequences > generation_config.num_beams:
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/generation/utils.py:2468, in GenerationMixin.sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2465 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2467 # forward pass to get next token
# -> 2468 outputs = self(
#    2469     **model_inputs,
#    2470     return_dict=True,
#    2471     output_attentions=output_attentions,
#    2472     output_hidden_states=output_hidden_states,
#    2473 )
#    2475 if synced_gpus and this_peer_finished:
#    2476     continue  # don't waste resources running the code we don't need
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:1704, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1701         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1703 # Decode
# -> 1704 decoder_outputs = self.decoder(
#    1705     input_ids=decoder_input_ids,
#    1706     attention_mask=decoder_attention_mask,
#    1707     inputs_embeds=decoder_inputs_embeds,
#    1708     past_key_values=past_key_values,
#    1709     encoder_hidden_states=hidden_states,
#    1710     encoder_attention_mask=attention_mask,
#    1711     head_mask=decoder_head_mask,
#    1712     cross_attn_head_mask=cross_attn_head_mask,
#    1713     use_cache=use_cache,
#    1714     output_attentions=output_attentions,
#    1715     output_hidden_states=output_hidden_states,
#    1716     return_dict=return_dict,
#    1717 )
#    1719 sequence_output = decoder_outputs[0]
#    1721 # Set device for model parallelism
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:1074, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1061     layer_outputs = checkpoint(
#    1062         create_custom_forward(layer_module),
#    1063         hidden_states,
#    (...)
#    1071         None,  # past_key_value is always None with gradient checkpointing
#    1072     )
#    1073 else:
# -> 1074     layer_outputs = layer_module(
#    1075         hidden_states,
#    1076         attention_mask=extended_attention_mask,
#    1077         position_bias=position_bias,
#    1078         encoder_hidden_states=encoder_hidden_states,
#    1079         encoder_attention_mask=encoder_extended_attention_mask,
#    1080         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1081         layer_head_mask=layer_head_mask,
#    1082         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1083         past_key_value=past_key_value,
#    1084         use_cache=use_cache,
#    1085         output_attentions=output_attentions,
#    1086     )
#    1088 # layer_outputs is a tuple with:
#    1089 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1090 if use_cache is False:
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:719, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     716 else:
#     717     query_length = None
# --> 719 cross_attention_outputs = self.layer[1](
#     720     hidden_states,
#     721     key_value_states=encoder_hidden_states,
#     722     attention_mask=encoder_attention_mask,
#     723     position_bias=encoder_decoder_position_bias,
#     724     layer_head_mask=cross_attn_layer_head_mask,
#     725     past_key_value=cross_attn_past_key_value,
#     726     query_length=query_length,
#     727     use_cache=use_cache,
#     728     output_attentions=output_attentions,
#     729 )
#     730 hidden_states = cross_attention_outputs[0]
#     732 # clamp inf values to enable fp16 training
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:633, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     621 def forward(
#     622     self,
#     623     hidden_states,
#    (...)
#     631     output_attentions=False,
#     632 ):
# --> 633     normed_hidden_states = self.layer_norm(hidden_states)
#     634     attention_output = self.EncDecAttention(
#     635         normed_hidden_states,
#     636         mask=attention_mask,
#    (...)
#     643         output_attentions=output_attentions,
#     644     )
#     645     layer_output = hidden_states + self.dropout(attention_output[0])
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/miniconda3/envs/jupyter/lib/python3.9/site-packages/transformers/models/t5/modeling_t5.py:254, in T5LayerNorm.forward(self, hidden_states)
#     247 def forward(self, hidden_states):
#     248     # T5 uses a layer_norm which only scales and doesn't shift, which is also known as Root Mean
#     249     # Square Layer Normalization https://arxiv.org/abs/1910.07467 thus varience is calculated
#     250     # w/o mean and there is no bias. Additionally we want to make sure that the accumulation for
#     251     # half-precision inputs is done in fp32
#     253     variance = hidden_states.to(torch.float32).pow(2).mean(-1, keepdim=True)
# --> 254     hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     256     # convert into half-precision if necessary
#     257     if self.weight.dtype in [torch.float16, torch.bfloat16]:
#
# KeyboardInterrupt:

# %%
tasks[0]

# %%
len(tasks[1])
# Out:
# 966

# %%
len(tasks)
# Out:
# 2

# %%
import datetime
import os
import random
import pandas as pd
import numpy as np
import operator
import random
from tqdm import tqdm
import dill
try:
    import binutil  # required to import from dreamcoder modules
except ModuleNotFoundError:
    import bin.binutil  # alt import if called as module

from dreamcoder.task import Task
from dreamcoder.dreamcoder import *
from dreamcoder.domains.minatar.primitives import basePrimitives, tmap, taction
from dreamcoder.grammar import Grammar
from dreamcoder.utilities import testTrainSplit, eprint, numberOfCPUs
from dreamcoder.type import arrow
from dreamcoder.domains.minatar.feature_extractor import *
from dreamcoder.dreamcoder import commandlineArguments
from dreamcoder.utilities import numberOfCPUs
from dreamcoder.domains.minatar.feature_extractor import convert_to_task_input
from dreamcoder.domains.minatar.utils_text_encoder import generate_samples_with_temp
from transformers import RobertaTokenizer, T5ForConditionalGeneration
from dreamcoder.domains.minatar.utilities import *
os.environ["WANDB_PROJECT"] = "T5-Minatar"


def makeTasks(data, env_name, chunkSize, tolist=False):
    tasks = []
    examples = []
    part = 0
    states, actions, reward = data

    state_action_pairs = list(zip(states, actions))

    for i in range(len(state_action_pairs) - chunkSize):
        examples = []
        for state, action in state_action_pairs[i: i + chunkSize]:
            input_ex = (convert_to_task_input(
                state, jax_data=True, tolist=tolist),)
            output_ex = int(action)
            examples.append((input_ex, output_ex))

        # we check that the chosen actions are not all the same
        # otherwise it is too easy to find a program if all actions/output examples are the same
        # this results in programs such as (lambda (lambda forward-action))
        all_chosen_actions = list(zip(*examples))[1]
        if not all_equal(all_chosen_actions) and len(examples) == chunkSize:
            tasks.append(Task(f'{env_name} size {chunkSize} part {part}',
                              arrow(tmap, taction), examples))
            part += 1
    return tasks


def evaluate_enumerative_search(testingTasks, path, feature_extractor_class=MinatarFeatureExtractorToken):
    with open(path, "rb") as handle:
        result = dill.load(handle)
    resume = len(result.grammars) - 1
    eprint("Loaded checkpoint from", path)
    grammar = result.grammars[-1] if result.grammars else grammar
    args = commandlineArguments(
        enumerationTimeout=120,
        structurePenalty=1.5,
        recognitionSteps=5000,
        biasOptimal=False,
        contextual=False,
        a=3,
        topK=5,
        iterations=1,
        useRecognitionModel=True,
        helmholtzRatio=0.5,
        featureExtractor=feature_extractor_class,
        maximumFrontier=10,
        CPUs=numberOfCPUs(),
        pseudoCounts=30.0,
        extras=None)
    times = evaluateOnTestingTasks(result, testingTasks, grammar,
                                   CPUs=args.get('CPUs'), maximumFrontier=args.get('maximumFrontier'),
                                   solver=args.get('solver'),
                                   enumerationTimeout=args.get('enumerationTimeout'), evaluationTimeout=args.get('enumerationTimeout'))

    return times


def evaluate_model(data, path, env_name, results_path, feature_extractor_class):
    # first check if a csv exists and load the csv then and start after last seq lenght...
    solved_tasks = []
    idx = []
    start_iter = 3
    if os.path.exists(results_path):
        df = pd.read_csv(results_path, index_col=0)
        idx = list(df.index)
        solved, all_tasks = df.to_dict('list').values()
        for s, a in zip(solved, all_tasks):
            solved_tasks.append({
                'solved': s,
                'tasks': a
            })
        print(f'loaded from {results_path}')
        print('start from found csv file:', solved_tasks)
        print('index:', idx)
        start_iter = idx[-1] + 1

    sequence_lengths = range(start_iter, 31)
    for i in sequence_lengths:
        tasks = makeTasks(data, env_name, i, tolist=True)
        print(f'created {len(tasks)} tasks')
        hits = evaluate_enumerative_search(
            tasks, path, feature_extractor_class=feature_extractor_class)
        # return method(tasks, path, env_name)
        solved_tasks.append({
            'solved': hits,
            'tasks': len(tasks)
        })
        idx.append(i)
        df = pd.DataFrame(solved_tasks, index=idx)
        df.to_csv(results_path)
    return df


if __name__ == '__main__':
    env_name = 'asterix'
    data = np.load(
        f"/home/ma/e/eberhardinger/workspaces/gymnax-blines/notebooks/{env_name}/rollouts.npy", allow_pickle=True)[0]

    path = '/home/ma/e/eberhardinger/workspaces/ec/experimentOutputs/asterix/CORRECT_clear-frontiers/2023-05-14T18:44:17.138576/'
    ckpt = f'asterix_aic=1.0_arity=3_BO=False_CO=False_ES=1_ET=720_env_name=asterix_HR=0.5_it=3_MF=10_noConsolidation=False_pc=30.0_RS=5000_RT=720_RR=False_RW=False_solver=python_STM=True_L=1.5_TRR=default_K=5_topkNotMAP=False.pickle'

    ckpt_path = os.path.join(path, ckpt)

    if 'graph=True.pickle' in ckpt:
        results_path = os.path.join(path, 'eval.csv')
    else:
        results_path = os.path.join(path, 'eval_nn.csv')

    print(f'Save results in: {results_path}')
    Grammar.uniform(basePrimitives(env_name))
    evaluate_model(data, ckpt_path, env_name,
                   results_path, feature_extractor_class=CNNFeatureExtractor)
# Out:
# Save results in: /home/ma/e/eberhardinger/workspaces/ec/experimentOutputs/asterix/CORRECT_clear-frontiers/2023-05-14T18:44:17.138576/eval_nn.csv
# created 508 tasks
# Loaded checkpoint from /home/ma/e/eberhardinger/workspaces/ec/experimentOutputs/asterix/CORRECT_clear-frontiers/2023-05-14T18:44:17.138576/asterix_aic=1.0_arity=3_BO=False_CO=False_ES=1_ET=720_env_name=asterix_HR=0.5_it=3_MF=10_noConsolidation=False_pc=30.0_RS=5000_RT=720_RR=False_RW=False_solver=python_STM=True_L=1.5_TRR=default_K=5_topkNotMAP=False.pickle
# CUDA is available?: False
# using cuda?: False
# use recognitionModel
# Evaluated recognition model in 0.7 seconds
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
#
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 0.000000 <= MDL < 1.500000. Timeout 120.000000.
# 0.000000, 1.500000, 120.000000s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# ...
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.717405.
# 1.500000, 3.000000, 97.717405s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.742785.
# 1.500000, 3.000000, 97.742785s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.753935.
# 1.500000, 3.000000, 97.753935s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.781155.
# 1.500000, 3.000000, 97.781155s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.792776.
# 1.500000, 3.000000, 97.792776s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.799738.
# 1.500000, 3.000000, 97.799738s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.851035.
# 1.500000, 3.000000, 97.851035s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.849240.
# 1.500000, 3.000000, 97.849240s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.881585.
# 1.500000, 3.000000, 97.881585s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.885160.
# 1.500000, 3.000000, 97.885160s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.850323.
# 1.500000, 3.000000, 97.850323s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.849162.
# 1.500000, 3.000000, 97.849162s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.894185.
# 1.500000, 3.000000, 97.894185s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.898835.
# 1.500000, 3.000000, 97.898835s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 97.987660.
# 1.500000, 3.000000, 97.987660s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.072871.
# 1.500000, 3.000000, 98.072871s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.143500.
# 1.500000, 3.000000, 98.143500s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.198534.
# 1.500000, 3.000000, 98.198534s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.281683.
# 1.500000, 3.000000, 98.281683s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.352468.
# 1.500000, 3.000000, 98.352468s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.431260.
# 1.500000, 3.000000, 98.431260s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.485151.
# 1.500000, 3.000000, 98.485151s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.575999.
# 1.500000, 3.000000, 98.575999s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.653480.
# 1.500000, 3.000000, 98.653480s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.743153.
# 1.500000, 3.000000, 98.743153s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 98.846130.
# 1.500000, 3.000000, 98.846130s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.031246.
# 1.500000, 3.000000, 99.031246s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.206769.
# 1.500000, 3.000000, 99.206769s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.407885.
# 1.500000, 3.000000, 99.407885s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.619075.
# 1.500000, 3.000000, 99.619075s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.794353.
# 1.500000, 3.000000, 99.794353s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.794562.
# 1.500000, 3.000000, 99.794562s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.793554.
# 1.500000, 3.000000, 99.793554s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.816707.
# 1.500000, 3.000000, 99.816707s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.836668.
# 1.500000, 3.000000, 99.836668s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.862485.
# 1.500000, 3.000000, 99.862485s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.902692.
# 1.500000, 3.000000, 99.902692s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.930569.
# 1.500000, 3.000000, 99.930569s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.953986.
# 1.500000, 3.000000, 99.953986s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.963627.
# 1.500000, 3.000000, 99.963627s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 99.992538.
# 1.500000, 3.000000, 99.992538s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.007862.
# 1.500000, 3.000000, 100.007862s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.031312.
# 1.500000, 3.000000, 100.031312s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.038890.
# 1.500000, 3.000000, 100.038890s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.069991.
# 1.500000, 3.000000, 100.069991s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.143784.
# 1.500000, 3.000000, 100.143784s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.155766.
# 1.500000, 3.000000, 100.155766s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.165656.
# 1.500000, 3.000000, 100.165656s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.184070.
# 1.500000, 3.000000, 100.184070s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.196509.
# 1.500000, 3.000000, 100.196509s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.224579.
# 1.500000, 3.000000, 100.224579s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.237103.
# 1.500000, 3.000000, 100.237103s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.276103.
# 1.500000, 3.000000, 100.276103s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.280919.
# 1.500000, 3.000000, 100.280919s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.303389.
# 1.500000, 3.000000, 100.303389s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.317439.
# 1.500000, 3.000000, 100.317439s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.317181.
# 1.500000, 3.000000, 100.317181s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.326526.
# 1.500000, 3.000000, 100.326526s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.339401.
# 1.500000, 3.000000, 100.339401s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.354605.
# 1.500000, 3.000000, 100.354605s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.369432.
# 1.500000, 3.000000, 100.369432s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.370091.
# 1.500000, 3.000000, 100.370091s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.364349.
# 1.500000, 3.000000, 100.364349s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.380084.
# 1.500000, 3.000000, 100.380084s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.470206.
# 1.500000, 3.000000, 100.470206s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.628531.
# 1.500000, 3.000000, 100.628531s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.755889.
# 1.500000, 3.000000, 100.755889s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 100.887452.
# 1.500000, 3.000000, 100.887452s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.011428.
# 1.500000, 3.000000, 101.011428s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.159698.
# 1.500000, 3.000000, 101.159698s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.344293.
# 1.500000, 3.000000, 101.344293s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.542401.
# 1.500000, 3.000000, 101.542401s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.689897.
# 1.500000, 3.000000, 101.689897s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.805853.
# 1.500000, 3.000000, 101.805853s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 101.957690.
# 1.500000, 3.000000, 101.957690s
# 	(ocaml: 1 CPUs. shatter: 1. |fringe| = 1. |finished| = 0.)
# (frontend) Launching array(array(tobj)) -> taction (1 tasks) w/ 1 CPUs. 1.500000 <= MDL < 3.000000. Timeout 102.083555.
